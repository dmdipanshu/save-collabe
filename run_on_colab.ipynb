# %% [markdown]
# ### Run Telegram Bot on Google Colab
# This single notebook contains all the source code required to run the bot.
# No need to mount Google Drive or upload files manually!

# %%
import base64
import zipfile
import io
import os

bot_dir = "/content/bot"
os.makedirs(bot_dir, exist_ok=True)
os.chdir(bot_dir)

print("Extracting bot code...")
zip_data = "..."
with zipfile.ZipFile(io.BytesIO(base64.b64decode(zip_data))) as z:
    z.extractall()
print("Code extracted successfully!")

# %%
print("Installing dependencies...")
# !pip install -r requirements.txt > /dev/null
# !apt-get update > /dev/null
# !apt-get install -y ffmpeg > /dev/null
print("Dependencies installed!")

# %%
# Configure your variables here OR directly in config.py!
import os

# os.environ["API_ID"] = "123456"
# os.environ["API_HASH"] = "your_api_hash"
# os.environ["BOT_TOKEN"] = "your_bot_token"

# !python main.py
