# %% [markdown]
# ### Run Telegram Bot on Google Colab
# Upload this folder to Google Drive before running.

# %%
from google.colab import drive
import os

print("Mounting Google Drive...")
drive.mount('/content/drive')

# ⚠️ Change this path if your folder name is different in your Google Drive
BOT_DIR = "/content/drive/MyDrive/Save-Restricted-Content-Bot-v3-main"

if not os.path.exists(BOT_DIR):
    print(f"❌ Error: Could not find the folder at {BOT_DIR}")
    print("Please check the folder name and make sure it is in the root of your Google Drive.")
else:
    # %cd "{BOT_DIR}"
    print("✅ Folder found! Installing dependencies...")
    
    # Install all required libraries
    # !pip install -r requirements.txt
    
    # Install ffmpeg for video thumbnail processing
    # !apt-get install -y ffmpeg
    
    print("🎉 Setup complete! You can now run the bot.")

# %%
# %cd "{BOT_DIR}"

# Run the bot
# !python main.py
